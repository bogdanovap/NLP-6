# %% [markdown]
# ### Часть 2. Тематическое моделирование
# 1. Постройте несколько тематических моделей коллекции документов с разным числом тем. Приведите примеры понятных (интерпретируемых) тем.
# 2. Найдите темы, в которых упомянуты конкретные банки (Сбербанк, ВТБ, другой банк). Можете ли вы их прокомментировать / объяснить?
# Эта часть задания может быть сделана с использованием gensim.

# %%
import json

import bz2
import re

from tqdm import tqdm
import pandas as pd
# %matplotlib inline
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Загружаем данные и готовим DF

# %%
responses = []
with bz2.BZ2File('banki_responses.json.bz2', 'r') as thefile:
    for row in tqdm(thefile):
        resp = json.loads(row)
        if not resp['rating_not_checked'] and (len(resp['text'].split()) > 0):
            responses.append(resp)
# Out:
# 201030it [01:02, 3228.78it/s]

# %%
df = pd.DataFrame(responses)

# %% [markdown]
# Функции для подготовки текста для последующего анализа
# - стоп слова
# - лемматизация
# - токенизация через регулярку (только слова из русских букв) и последующий split

# %%
from string import punctuation
from nltk.corpus import stopwords

stops  = stopwords.words('russian') + list(punctuation) + ["``", "''"] + [
    'это', 'наш' , 'тыс', 'млн', 'млрд', 'также',  'т', 'д',
    'который','прошлый','сей', 'свой', 'наш', 'мочь', 'такой'
]
ru_words = re.compile("[А-Яа-я]+")

# %%
from pymorphy3 import MorphAnalyzer
morph = MorphAnalyzer()

# %%
def words_only(text):
    return " ".join(ru_words.findall(text))

# def lemmatize(text, mystem=m):
#     try:
#         return "".join(m.lemmatize(text)).strip()
#     except:
#         return " "

def lemmatize(text, mystem=morph):
    try:
        return " ".join([mystem.parse(w)[0].normal_form for w in text.split(' ')]).strip()
    except:
        return " "

def remove_stopwords(text, mystopwords = stops):
    try:
        return " ".join([token for token in text.split() if not token in mystopwords])
    except:
        return ""

def preprocess(text):
    return remove_stopwords(lemmatize(words_only(text.lower())))

# %%
# %%time
df_analyze = df[:1000].copy()
df_analyze.text = df_analyze.text.apply(preprocess)
# Out:
# CPU times: total: 41.4 s
# Wall time: 41.3 s

# %% [markdown]
# Создаем и тренируем модели с разным количеством тем (5, 15, 30)

# %%
from gensim.corpora import Dictionary
from gensim.models import TfidfModel, lsimodel
from gensim import similarities

# %%
texts = [text.split() for text in df_analyze.text]
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
tfidf = TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
n_topics = [5, 15, 30]
lsi_models = {}
for n in n_topics:
    lsi_models[n] = lsimodel.LsiModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=n)

# %%
lsi_models[30].show_topics(30)
# Out:
# [(0,
#   '0.194*"карта" + 0.152*"вклад" + 0.145*"кредит" + 0.113*"деньга" + 0.107*"сумма" + 0.105*"счёт" + 0.096*"договор" + 0.096*"сотрудник" + 0.095*"отделение" + 0.094*"заявление"'),
#  (1,
#   '-0.572*"вклад" + -0.298*"ставка" + -0.263*"пополнение" + -0.205*"условие" + -0.123*"односторонний" + -0.117*"изменение" + -0.115*"вкладчик" + -0.114*"договор" + 0.104*"кредит" + 0.104*"звонок"'),
#  (2,
#   '-0.245*"звонок" + 0.234*"карта" + -0.217*"номер" + -0.166*"телефон" + -0.156*"данные" + -0.156*"ваш" + -0.155*"согласие" + -0.149*"персональный" + -0.144*"удалить" + -0.132*"давать"'),
#  (3,
#   '0.421*"страховка" + 0.358*"страхование" + 0.332*"кредит" + -0.188*"карта" + 0.150*"договор" + -0.127*"банкомат" + -0.124*"номер" + 0.113*"отказаться" + 0.112*"досрочный" + 0.106*"отказ"'),
#  (4,
#   '0.209*"задолженность" + 0.174*"сумма" + 0.165*"платёж" + 0.160*"средство" + 0.143*"погашение" + 0.132*"денежный" + 0.130*"руб" + -0.129*"отделение" + -0.129*"офис" + 0.122*"комиссия"'),
#  (5,
#   '0.242*"страхование" + 0.240*"страховка" + 0.222*"сбербанк" + 0.145*"вернуть" + 0.136*"денежный" + 0.135*"средство" + -0.129*"платёж" + 0.128*"г" + -0.125*"просрочка" + 0.119*"возврат"'),
#  (6,
#   '-0.331*"карта" + 0.223*"банкомат" + -0.214*"р" + 0.213*"сбербанк" + -0.181*"комиссия" + -0.172*"лимит" + -0.135*"страховка" + 0.134*"денежный" + 0.121*"средство" + 0.106*"погашение"'),
#  (7,
#   '-0.470*"банкомат" + -0.198*"микрорайон" + -0.160*"р" + -0.131*"капланово" + 0.127*"счёт" + 0.116*"документ" + 0.106*"заявка" + -0.106*"кредит" + -0.103*"страховка" + -0.097*"житель"'),
#  (8,
#   '-0.252*"карта" + 0.156*"сумма" + -0.155*"лимит" + -0.152*"кредитный" + 0.144*"р" + 0.144*"деньга" + 0.139*"счёт" + -0.134*"банкомат" + -0.131*"сбербанк" + 0.126*"платёж"'),
#  (9,
#   '-0.414*"р" + 0.164*"договор" + -0.147*"г" + -0.120*"вклад" + -0.099*"очередь" + -0.099*"открыть" + -0.098*"офис" + -0.098*"поэтому" + 0.094*"номер" + 0.093*"смс"'),
#  (10,
#   '-0.191*"перевод" + -0.188*"комиссия" + 0.148*"карта" + -0.133*"документ" + 0.133*"вклад" + 0.127*"горячий" + -0.125*"киви" + 0.125*"отделение" + 0.124*"линия" + 0.114*"заявление"'),
#  (11,
#   '0.483*"сбербанк" + -0.210*"банкомат" + 0.203*"р" + -0.168*"страховка" + 0.111*"отделение" + 0.101*"платёж" + -0.097*"ваш" + -0.095*"форс" + -0.095*"мажор" + -0.094*"предполагаться"'),
#  (12,
#   '-0.272*"комиссия" + 0.201*"сбербанк" + 0.194*"р" + -0.181*"счёт" + -0.173*"руб" + -0.131*"банкомат" + 0.130*"ставка" + 0.119*"операция" + -0.118*"заявление" + 0.113*"списание"'),
#  (13,
#   '-0.231*"р" + 0.189*"кредит" + 0.171*"комиссия" + -0.147*"депозит" + 0.143*"номер" + 0.139*"сбербанк" + 0.130*"заявка" + 0.126*"счёт" + 0.124*"руб" + 0.120*"вклад"'),
#  (14,
#   '-0.264*"сбербанк" + 0.229*"заявка" + 0.162*"р" + 0.160*"банкомат" + -0.159*"страховка" + 0.156*"лимит" + 0.128*"персональный" + -0.123*"страхование" + 0.121*"кредит" + -0.108*"списание"'),
#  (15,
#   '-0.175*"заявка" + -0.160*"ставка" + -0.156*"счёт" + -0.148*"сбербанк" + -0.147*"кредит" + 0.138*"р" + -0.137*"комиссия" + 0.136*"вклад" + 0.129*"платёж" + 0.122*"страхование"'),
#  (16,
#   '-0.270*"лимит" + -0.216*"р" + -0.128*"денежный" + -0.123*"кредитный" + 0.123*"ставка" + 0.122*"услуга" + -0.122*"звонить" + -0.118*"средство" + 0.110*"заявление" + -0.103*"документ"'),
#  (17,
#   '-0.193*"р" + -0.184*"депозит" + 0.180*"лимит" + -0.133*"ставка" + 0.133*"вклад" + 0.111*"сч" + -0.108*"страхование" + -0.107*"номер" + -0.098*"комиссия" + -0.098*"услуга"'),
#  (18,
#   '0.196*"терминал" + 0.151*"руб" + 0.141*"очередь" + -0.140*"микрорайон" + 0.125*"купюра" + -0.124*"заявление" + -0.124*"город" + -0.121*"смс" + 0.117*"отделение" + 0.113*"рубль"'),
#  (19,
#   '-0.268*"карта" + 0.240*"лимит" + -0.164*"терминал" + -0.112*"дебетовый" + 0.112*"обращение" + 0.111*"руб" + 0.110*"смс" + 0.102*"евро" + 0.101*"банкомат" + 0.099*"операция"'),
#  (20,
#   '-0.152*"счёт" + 0.151*"комиссия" + 0.150*"депозит" + -0.122*"платёж" + -0.117*"страхование" + 0.116*"руб" + -0.115*"смс" + 0.108*"документ" + 0.105*"пожалуйста" + 0.105*"евро"'),
#  (21,
#   '0.215*"терминал" + -0.173*"сч" + -0.147*"комиссия" + -0.132*"деньга" + 0.130*"микрорайон" + 0.125*"сумма" + -0.121*"линия" + -0.119*"горячий" + 0.115*"рубль" + -0.115*"перевод"'),
#  (22,
#   '0.191*"сч" + 0.148*"лимит" + 0.146*"долг" + 0.137*"депозит" + -0.129*"смс" + 0.120*"альфа" + 0.116*"страхование" + 0.113*"кредитный" + 0.113*"русский" + -0.112*"р"'),
#  (23,
#   '0.179*"договор" + -0.176*"ставка" + 0.169*"депозит" + -0.143*"евро" + -0.141*"терминал" + 0.118*"втб" + -0.112*"сайт" + 0.110*"технический" + 0.100*"документ" + 0.098*"процент"'),
#  (24,
#   '-0.336*"депозит" + -0.206*"лимит" + 0.144*"заявка" + 0.127*"руб" + 0.119*"втб" + -0.119*"отделение" + -0.108*"прекратить" + -0.106*"давать" + -0.104*"заявление" + 0.098*"долг"'),
#  (25,
#   '-0.190*"руб" + 0.172*"кредит" + 0.144*"операция" + -0.115*"платёж" + -0.110*"сч" + 0.106*"г" + -0.105*"микрорайон" + -0.101*"документ" + -0.099*"киви" + -0.099*"долг"'),
#  (26,
#   '-0.173*"депозит" + -0.157*"заявка" + 0.155*"номер" + 0.145*"сч" + 0.121*"погашение" + -0.117*"звонок" + 0.100*"кошелёк" + -0.098*"муж" + 0.096*"киви" + -0.096*"рассмотрение"'),
#  (27,
#   '0.134*"договор" + 0.134*"офис" + 0.128*"смс" + -0.113*"процент" + 0.112*"деньга" + 0.110*"терминал" + -0.099*"прекратить" + 0.094*"цб" + -0.093*"сумма" + 0.092*"восточный"'),
#  (28,
#   '0.164*"ваш" + 0.158*"офис" + -0.135*"сч" + 0.131*"сотрудник" + -0.120*"смс" + -0.119*"депозит" + 0.119*"ставка" + -0.118*"восточный" + -0.115*"май" + -0.111*"стандарт"'),
#  (29,
#   '-0.188*"ставка" + 0.128*"ваш" + 0.126*"условие" + -0.126*"оператор" + -0.112*"купюра" + 0.106*"изменение" + 0.100*"офис" + 0.098*"деньга" + 0.096*"номер" + -0.094*"средство"')]

# %% [markdown]
# Пример темы, в которой можно понять смысл сообщений:
# (4,
#   '0.209*"задолженность" + 0.174*"сумма" + 0.165*"платёж" + 0.160*"средство" + 0.143*"погашение" + 0.132*"денежный" + 0.130*"руб" + -0.129*"отделение" + -0.129*"офис" + 0.122*"комиссия"'),
#
# Вероятно, речь идет о возможности погасить задолженность в отделении банка

# %%
for t in range(lsi_models[30].num_topics):
    if "сбербанк" in lsi_models[30].print_topic(t):
        print(t, ":\n",  lsi_models[30].show_topic(t))
# Out:
# 5 :
#  [('страхование', 0.24202996972745808), ('страховка', 0.24022042711689728), ('сбербанк', 0.22165165508964155), ('вернуть', 0.1450802803665642), ('денежный', 0.13572301578470827), ('средство', 0.1347369219794901), ('платёж', -0.12941492068460017), ('г', 0.12835119588206267), ('просрочка', -0.12532210679099992), ('возврат', 0.11901467127635443)]
# 6 :
#  [('карта', -0.330924789982194), ('банкомат', 0.22258735768569995), ('р', -0.2138724454167469), ('сбербанк', 0.21258679259677565), ('комиссия', -0.18144332625854226), ('лимит', -0.17233564304357543), ('страховка', -0.1345903648677649), ('денежный', 0.134366230567053), ('средство', 0.12065006362415427), ('погашение', 0.10617427340972226)]
# 8 :
#  [('карта', -0.2516947907897725), ('сумма', 0.15557570018855638), ('лимит', -0.1554308432199808), ('кредитный', -0.1517421876208719), ('р', 0.14354934996731883), ('деньга', 0.1435057243688443), ('счёт', 0.13948132859324103), ('банкомат', -0.13355482349444422), ('сбербанк', -0.13130699945257177), ('платёж', 0.12584135679516734)]
# 11 :
#  [('сбербанк', 0.4830088866775441), ('банкомат', -0.20985581191674263), ('р', 0.20301355384381342), ('страховка', -0.16846640789878767), ('отделение', 0.11105372666329763), ('платёж', 0.10050560489477753), ('ваш', -0.09661276652624312), ('форс', -0.09451325657694774), ('мажор', -0.09451325657694774), ('предполагаться', -0.09422986139106933)]
# 12 :
#  [('комиссия', -0.2721835232168738), ('сбербанк', 0.20085266968359552), ('р', 0.19406694593964413), ('счёт', -0.18081688865946216), ('руб', -0.17274164165581193), ('банкомат', -0.13108095597348746), ('ставка', 0.12998271165987277), ('операция', 0.1187949140104658), ('заявление', -0.11752529515870029), ('списание', 0.11256877794513227)]
# 13 :
#  [('р', -0.23108158211021), ('кредит', 0.18858187680058341), ('комиссия', 0.17058105396876072), ('депозит', -0.1466865167096928), ('номер', 0.14250246296465643), ('сбербанк', 0.1391524523757056), ('заявка', 0.13013342248475887), ('счёт', 0.12599126227769544), ('руб', 0.1241175067136505), ('вклад', 0.12034247213315842)]
# 14 :
#  [('сбербанк', -0.26448347831621777), ('заявка', 0.22944819018883295), ('р', 0.16183780545575252), ('банкомат', 0.16006904696279262), ('страховка', -0.15928024129179696), ('лимит', 0.15558863911204052), ('персональный', 0.12848968283319379), ('страхование', -0.12269124445805532), ('кредит', 0.12065687692279704), ('списание', -0.10795009462015887)]
# 15 :
#  [('заявка', -0.17543846863176452), ('ставка', -0.16031165330239738), ('счёт', -0.15593032076575025), ('сбербанк', -0.14809408802940832), ('кредит', -0.14704731988204037), ('р', 0.13829194596851999), ('комиссия', -0.13662323822216818), ('вклад', 0.1361756563772901), ('платёж', 0.12920840107127532), ('страхование', 0.1218046328370249)]

# %% [markdown]
# При разбиении на 30 тем, можно найти ряд тем содержащих "сбербанк"
# Некоторые из них можно достаточно легко пркомментировать.
# Например, тема 6 явно связана с погашением кредита/креитной карты
